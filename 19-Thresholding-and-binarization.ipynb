# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">تصاویر باینری و حد آستانه</div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در ابتدا با numpy تصویر را باینری می‌کنیم.
# </div>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
import os

# اتصال به Google Drive
drive.mount('/content/drive')

# مسیر فایل ورودی (لطفاً مسیر دقیق را جایگزین کنید)
image_path = '/content/drive/My Drive/images/gradient.jpg'



# Load our image as greyscale
image = cv2.imread(image_path)

new_image = np.copy(image)
new_image[new_image <  170] = 0
new_image[new_image >= 170] = 255


plt.figure(figsize=[10,5])
plt.subplot(121);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(122);plt.imshow(new_image, cmap='gray');plt.title("Output");
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# و خروجی با تصویر در دنیای واقعی</div>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = '/content/drive/My Drive/images/Lusin-1.jpg'



image = cv2.imread(image_path)

# Load our image as greyscale
image = cv2.imread(image_path, 0)

new_image = np.copy(image)
new_image[new_image <  127] = 0
new_image[new_image >= 127] = 255

plt.figure(figsize=[10,5])
plt.subplot(121);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(122);plt.imshow(new_image, cmap='gray');plt.title("Output");

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# برای اینکار می‌توانیم از تابع threshold در opencv استفاده کنیم
# </div>

# %% [markdown]
# `threshold(src, thresh, maxval, type[, dst])`
#
# `maxval` : maximum value to use with the #THRESH_BINARY and #THRESH_BINARY_INV thresholding

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = '/content/drive/My Drive/images/gradient.jpg'

# Load our image as greyscale
image = cv2.imread(image_path,0)

# Values below 127 goes to 0 (black, everything above goes to 255 (white)
ret,new_image = cv2.threshold(image, 60, 255, cv2.THRESH_BINARY)
print(ret)
plt.figure(figsize=[10,5])
plt.subplot(121);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(122);plt.imshow(new_image, cmap='gray');plt.title("Output");
# Out:
# 60.0

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# پارامترهای مختلف تابع threshold</div>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load our image as greyscale
image_path = '/content/drive/My Drive/images/gradient.jpg'

# Load our image as greyscale
image = cv2.imread(image_path,0)

# Values below 127 goes to 0 (black, everything above goes to 255 (white)
ret1,thresh1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Values below 127 go to 255 and values above 127 go to 0 (reverse of above)
ret2,thresh2 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV)

# Values above 127 are truncated (held) at 127 (the 255 argument is unused)
ret3,thresh3 = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)

# Values below 127 go to 0, above 127 are unchanged
ret4,thresh4 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO)

# Resever of above, below 127 is unchanged, above 127 goes to 0
ret5,thresh5 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO_INV)

plt.figure(figsize=[9,6])
plt.subplot(231);plt.imshow(thresh1, cmap='gray');plt.title("1 Threshold Binary");
plt.subplot(232);plt.imshow(thresh2, cmap='gray');plt.title("2 Threshold Binary Inverse");
plt.subplot(233);plt.imshow(thresh3, cmap='gray');plt.title("3 THRESH TRUNC");
plt.subplot(234);plt.imshow(thresh4, cmap='gray');plt.title("4 THRESH TOZERO");
plt.subplot(235);plt.imshow(thresh5, cmap='gray');plt.title("5 THRESH TOZERO INV");
plt.subplot(236);plt.imshow(image, cmap='gray');plt.title("Original");

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# اعمال حد آستانه با متدهای مختلف روی تصویر پلاک ماشین</div>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load our image as greyscale
image_path = '/content/drive/My Drive/images/plate.jpg'

# Load image in grayscale
image = cv2.imread(image_path, 0)

# نمایش تصویر اصلی با matplotlib
plt.figure(figsize=(5,5))
plt.imshow(image, cmap='gray')
plt.title('Original')
plt.axis('off')
plt.show()

# Thresholding operations
ret1, thresh1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
ret2, thresh2 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV)
ret3, thresh3 = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)
ret4, thresh4 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO)
ret5, thresh5 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO_INV)

# نمایش تصاویر Threshold شده
plt.figure(figsize=(15,8))
plt.subplot(231); plt.imshow(thresh1, cmap='gray'); plt.title("1 Threshold Binary"); plt.axis('off')
plt.subplot(232); plt.imshow(thresh2, cmap='gray'); plt.title("2 Threshold Binary Inverse"); plt.axis('off')
plt.subplot(233); plt.imshow(thresh3, cmap='gray'); plt.title("3 THRESH TRUNC"); plt.axis('off')
plt.subplot(234); plt.imshow(thresh4, cmap='gray'); plt.title("4 THRESH TOZERO"); plt.axis('off')
plt.subplot(235); plt.imshow(thresh5, cmap='gray'); plt.title("5 THRESH TOZERO INV"); plt.axis('off')
plt.subplot(236); plt.imshow(image, cmap='gray'); plt.title("Original"); plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# اعمال حدآستانه با رابط کاربری</div>

# %%
import cv2
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# مقادیر ثابت
max_value = 255
max_type = 4
max_binary_value = 255

# بارگذاری و تبدیل به grayscale
image_path = '/content/drive/My Drive/images/plate.jpg'
src = cv2.imread(image_path)
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# لیست نوع‌های threshold
thresh_type = ["Binary", "Binary Inverted", "Threshold Truncated", "Threshold to Zero", "Threshold to Zero Inverted"]

# تابع برای اعمال threshold و نمایش
def Threshold_Demo(threshold_value, threshold_type):
    _, dst = cv2.threshold(src_gray, threshold_value, max_binary_value, threshold_type)
    plt.figure(figsize=(6,6))
    plt.imshow(dst, cmap='gray')
    plt.title(f"Threshold: {threshold_value} | Type: {thresh_type[threshold_type]}")
    plt.axis('off')
    plt.show()

# اسلایدرها
threshold_value_slider = widgets.IntSlider(value=127, min=0, max=255, step=1, description='Value:')
threshold_type_slider = widgets.Dropdown(
    options=[(name, i) for i, name in enumerate(thresh_type)],
    value=0,
    description='Type:'
)

# نمایش widgets و اتصال به تابع
ui = widgets.VBox([threshold_value_slider, threshold_type_slider])

out = widgets.interactive_output(Threshold_Demo, {
    'threshold_value': threshold_value_slider,
    'threshold_type': threshold_type_slider
})

display(ui, out)
# Out:
# VBox(children=(IntSlider(value=127, description='Value:', max=255), Dropdown(description='Type:', options=(('B…
# Output()

# %% [markdown]
# https://docs.opencv.org/4.x/db/d8e/tutorial_threshold.html
